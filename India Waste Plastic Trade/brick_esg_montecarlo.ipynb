# %% [markdown]
# ### Monte Carlo Simulation with GBM of Total Recycled Plastic Waste

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as scs
import statistics

# %% [markdown]
# ##### SImulating Demand with Geometric Brownian Motion
#
# ### $$ dS_t  = \mu S_tdt + \sigma S_tdW_t $$
#
# Integrated Form:
#
# ### $$ S_t  = S_0e^{(\mu - \frac{\sigma^2}{2})t + \sigma W_t} $$

# %%
# Parameters
# drift coefficent
mu = 0.0625
# number of steps
n = 20
# time in years
T = 20
# number of sims
M = 10000
# initial demand
S0 = 1170000
# volatility
sigma = 0.0078
dt = T/n

# %%
np.random.seed(1)
# calc each time step
dt = T/n
# simulation using numpy arrays
demand = np.exp(
    (mu - sigma ** 2 / 2) * dt
    + sigma * np.random.normal(0, np.sqrt(dt), size=(M,n)).T
)
# include array of 1's
demand = np.vstack([np.ones(M), demand])
# multiply through by S0 and return the cumulative product of elements along a given simulation path axis=0. 
demand_trend = 1 * demand.cumprod(axis=0)
demand = S0 * demand.cumprod(axis=0)

# %%
demand_df =pd.DataFrame(demand.T)

# %%
pers = [0,5.0, 10,15,20,100]
var1 = scs.scoreatpercentile(demand_df[1], pers)
var2 = scs.scoreatpercentile(demand_df[2], pers)
var3 = scs.scoreatpercentile(demand_df[3], pers)
var4 = scs.scoreatpercentile(demand_df[4], pers)
var5 = scs.scoreatpercentile(demand_df[5], pers)
var6 = scs.scoreatpercentile(demand_df[6], pers)
var7 = scs.scoreatpercentile(demand_df[7], pers)
var8 = scs.scoreatpercentile(demand_df[8], pers)
var9 = scs.scoreatpercentile(demand_df[9], pers)
var10 = scs.scoreatpercentile(demand_df[10], pers)
var11 = scs.scoreatpercentile(demand_df[11], pers)
var12 = scs.scoreatpercentile(demand_df[12], pers)
var13 = scs.scoreatpercentile(demand_df[13], pers)
var14 = scs.scoreatpercentile(demand_df[14], pers)
var15 = scs.scoreatpercentile(demand_df[15], pers)
var16 = scs.scoreatpercentile(demand_df[16], pers)
var17 = scs.scoreatpercentile(demand_df[17], pers)
var18 = scs.scoreatpercentile(demand_df[18], pers)
var19 = scs.scoreatpercentile(demand_df[19], pers)
var20 = scs.scoreatpercentile(demand_df[20], pers)
var_df = pd.DataFrame({'Percentile' : pers, 
                       '2020' : var1,
                       '2021' : var2, 
                       '2022' : var3,
                       '2023' : var4, 
                       '2024' : var5,
                       '2025' : var6, 
                       '2026' : var7,
                       '2027' : var8, 
                       '2028' : var9,
                       '2029' : var10, 
                       '2030' : var11,
                       '2031' : var12, 
                       '2032' : var13,
                       '2033' : var14, 
                       '2034' : var15,
                       '2035' : var16, 
                       '2036' : var17,
                       '2037' : var18, 
                       '2038' : var19,
                       '2039' : var20})

# %%
var_df
#var_df.to_csv('var_df.csv', index=False)
# Out:
#    Percentile          2020          2021          2022          2023  \
# 0         0.0  1.211110e+06  1.266148e+06  1.338323e+06  1.404610e+06
# 1         5.0  1.229640e+06  1.302229e+06  1.380321e+06  1.464467e+06
# 2        10.0  1.233013e+06  1.307621e+06  1.387467e+06  1.473278e+06
# 3        15.0  1.235447e+06  1.311080e+06  1.391937e+06  1.478934e+06
# 4        20.0  1.237320e+06  1.313829e+06  1.395755e+06  1.483515e+06
# 5       100.0  1.283004e+06  1.397776e+06  1.498657e+06  1.601979e+06
#
#            2024          2025          2026          2027          2028  ...  \
# 0  1.482399e+06  1.567566e+06  1.665134e+06  1.769854e+06  1.876849e+06  ...
# 1  1.554579e+06  1.651021e+06  1.752942e+06  1.861789e+06  1.975997e+06  ...
# 2  1.564660e+06  1.662531e+06  1.765914e+06  1.875756e+06  1.992602e+06  ...
# 3  1.571323e+06  1.669753e+06  1.774632e+06  1.885767e+06  2.004604e+06  ...
# 4  1.576771e+06  1.675657e+06  1.781602e+06  1.893929e+06  2.013735e+06  ...
# 5  1.722013e+06  1.845813e+06  1.970257e+06  2.105472e+06  2.238471e+06  ...
#
#            2030          2031          2032          2033          2034  \
# 0  2.112283e+06  2.240781e+06  2.367111e+06  2.501591e+06  2.659122e+06
# 1  2.229230e+06  2.369927e+06  2.518317e+06  2.675809e+06  2.844022e+06
# 2  2.250780e+06  2.392131e+06  2.542101e+06  2.703352e+06  2.874310e+06
# 3  2.265272e+06  2.408607e+06  2.560647e+06  2.722683e+06  2.895010e+06
# 4  2.277290e+06  2.421391e+06  2.575562e+06  2.738728e+06  2.913271e+06
# 5  2.566504e+06  2.726238e+06  2.914773e+06  3.149030e+06  3.361156e+06
#
#            2035          2036          2037          2038          2039
# 0  2.796019e+06  2.955461e+06  3.133297e+06  3.314925e+06  3.513918e+06
# 1  3.022906e+06  3.211919e+06  3.412841e+06  3.629299e+06  3.856866e+06
# 2  3.056138e+06  3.246709e+06  3.453720e+06  3.671497e+06  3.904254e+06
# 3  3.079884e+06  3.272994e+06  3.481118e+06  3.700921e+06  3.938158e+06
# 4  3.098280e+06  3.294356e+06  3.502978e+06  3.727380e+06  3.965018e+06
# 5  3.580567e+06  3.822065e+06  4.053494e+06  4.332824e+06  4.659428e+06
#
# [6 rows x 21 columns]

# %%
#pop_trend = (np.ones(T+1) * 0.158879).cumsum() - 0.158879 + S0
#prod_trend = ((np.ones(n+1) * 1.0221045).cumprod()) * S0

production_cap = var_df.T[1]

# %%
production_cap[0] = S0
production_cap = np.array(production_cap)

# %%
from matplotlib.lines import Line2D
plt.figure(figsize=(16, 8), dpi=80)
sns.set(style="darkgrid")

plt.plot(demand)
#plt.plot(pop_trend, c ='k', linewidth=3.0)
plt.plot(production_cap, c ='k', linewidth=2.0, linestyle = 'dashed')
#plt.plot(prod_trend, c ='k', linewidth=3.0, linestyle = 'dashed')
plt.xlabel("Period (t)")
plt.ylabel("Number of Bricks per Year (millions)")
plt.title("GBM Monte Carlo Simulation for India Brick Demand")
plt.axvline(3, c='r')
plt.axvline(7, c='r')
plt.xlim([0, n])
x_ticks = np.arange(0, n+1, 1)
plt.xticks(x_ticks)

custom_lines = [Line2D([0], [0], c = 'r', lw=1),
                Line2D([0], [0], c = 'k', lw=1, linestyle = 'dashed')]

plt.legend(custom_lines, ['5 Yr Period', 'Production level'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16, 8), dpi=80)
sns.set(style="white")
sns.kdeplot(demand_df[3], c = 'orange')
sns.kdeplot(demand_df[4], c = 'g')
sns.kdeplot(demand_df[5], c = 'b')
sns.kdeplot(demand_df[6], c = 'y')
sns.kdeplot(demand_df[7], c = 'r')
plt.title("Distribution of Inida Brick Demand between 2022 and 2027")
plt.xlabel("Number of Bricks per Month (millions)")

custom_lines = [Line2D([0], [0], c = 'orange', lw=1),
                Line2D([0], [0], c = 'g', lw=1),
                Line2D([0], [0], c = 'b', lw=1), 
                Line2D([0], [0], c = 'y', lw=1), 
                Line2D([0], [0], c = 'r', lw=1), 
                Line2D([0], [0], c = 'k', lw=1, linestyle = 'dashed')]

plt.legend(custom_lines, ['2022', '2023', '2024', '2025', '2026', 'Production'])

color = ['orange','g','b','y','r']
months = [3,4,5,6,7]
for i in range(5):
    plt.axvline(production_cap[i+3], c=color[i], linestyle = 'dashed')

plt.show()

# %%
print("The most probable demand in 2027 is:\n" + str(demand_df[8].median()))
# Out:
# The most probable demand in 2027 is:
# 1912792.9564544302

# %% [markdown]
# ##### SImulating Total Polyethylene Waste Recycled
#
# ### $$ Recycled_t  = \sum_{x = 0}^{t}S_t * P $$
# S = Units sold\
# P = Plastic(kg) per unit

# %% [markdown]
# ##### Bayesian Optimisation Minimal Amount of Plastic per Brick to Achieve Benchmark

# %%
benchmark = 5000*2.747

# %%
def recycle_eval(P):
    R = (demand*P)
    recycled_df =pd.DataFrame(R.T)
    
    z = scs.percentileofscore(recycled_df[5], benchmark)
    z = abs(risk-z)
    return -z

# %%
#!pip install bayesian-optimization
from bayes_opt import BayesianOptimization

recycle_bo = BayesianOptimization(recycle_eval, {'P' : (0.5, 1.5)})
                              
# init_points=20, n_iter=100 for final pred
recycle_bo.maximize(init_points=50, n_iter=100, acq='ei')
# Out:
# |   iter    |  target   |     P     |
# -------------------------------------
# |  1        | -90.0     |  0.7702   |
# |  2        | -90.0     |  0.6306   |
# |  3        | -3.77     |  1.063    |
# |  4        | -10.0     |  1.341    |
# |  5        | -9.86     |  1.108    |
# |  6        | -90.0     |  0.5421   |
# |  7        | -10.0     |  1.145    |
# |  8        | -90.0     |  0.8913   |
# |  9        | -90.0     |  0.5721   |
# |  10       | -10.0     |  1.151    |
# |  11       | -87.97    |  0.9868   |
# |  12       | -10.0     |  1.281    |
# |  13       | -90.0     |  0.5505   |
# |  14       | -5.69     |  1.079    |
# |  15       | -90.0     |  0.7254   |
# |  16       | -90.0     |  0.6243   |
# |  17       | -90.0     |  0.7792   |
# |  18       | -9.98     |  1.127    |
# |  19       | -89.25    |  0.9783   |
# |  20       | -10.0     |  1.244    |
# |  21       | -90.0     |  0.6729   |
# |  22       | -85.11    |  0.9956   |
# |  23       | -10.0     |  1.215    |
# |  24       | -80.47    |  1.004    |
# |  25       | -90.0     |  0.5136   |
# |  26       | -90.0     |  0.8562   |
# |  27       | -10.0     |  1.173    |
# |  28       | -90.0     |  0.6229   |
# |  29       | -90.0     |  0.5073   |
# |  30       | -90.0     |  0.5216   |
# |  31       | -90.0     |  0.5135   |
# |  32       | -90.0     |  0.6841   |
# |  33       | -4.07     |  1.075    |
# |  34       | -90.0     |  0.5983   |
# |  35       | -10.0     |  1.334    |
# |  36       | -89.95    |  0.9546   |
# |  37       | -38.34    |  1.037    |
# |  38       | -10.0     |  1.19     |
# |  39       | -9.98     |  1.13     |
# |  40       | -10.0     |  1.284    |
# |  41       | -87.97    |  0.9868   |
# |  42       | -10.0     |  1.327    |
# |  43       | -10.0     |  1.499    |
# |  44       | -90.0     |  0.7713   |
# |  45       | -10.0     |  1.468    |
# |  46       | -10.0     |  1.376    |
# |  47       | -90.0     |  0.8694   |
# |  48       | -9.99     |  1.133    |
# |  49       | -9.98     |  1.125    |
# |  50       | -9.99     |  1.144    |
# |  51       | -0.16     |  1.068    |
# |  52       | -10.0     |  1.422    |
# |  53       | -10.0     |  1.4      |
# |  54       | -10.0     |  1.446    |
# |  55       | -10.0     |  1.485    |
# |  56       | -10.0     |  1.26     |
# |  57       | -0.05     |  1.068    |
# |  58       | -10.0     |  1.306    |
# |  59       | -10.0     |  1.361    |
# |  60       | -10.0     |  1.229    |
# |  61       | -0.03     |  1.068    |
# |  62       | -0.09     |  1.068    |
# |  63       | -0.15     |  1.068    |
# |  64       | -8.87     |  1.093    |
# |  65       | -0.22     |  1.068    |
# |  66       | -10.0     |  1.434    |
# |  67       | -0.44     |  1.069    |
# |  68       | -0.45     |  1.068    |
# |  69       | -10.0     |  1.202    |
# |  70       | -10.0     |  1.388    |
# |  71       | -90.0     |  0.8194   |
# |  72       | -10.0     |  1.457    |
# |  73       | -90.0     |  0.9228   |
# |  74       | -10.0     |  1.411    |
# |  75       | -0.54     |  1.069    |
# |  76       | -10.0     |  1.163    |
# |  77       | -10.0     |  1.296    |
# |  78       | -0.46     |  1.068    |
# |  79       | -10.0     |  1.269    |
# |  80       | -10.0     |  1.316    |
# |  81       | -10.0     |  1.352    |
# |  82       | -10.0     |  1.493    |
# |  83       | -0.54     |  1.067    |
# |  84       | -0.67     |  1.069    |
# |  85       | -15.13    |  1.053    |
# |  86       | -10.0     |  1.476    |
# |  87       | -10.0     |  1.181    |
# |  88       | -10.0     |  1.251    |
# |  89       | -9.48     |  1.1      |
# |  90       | -10.0     |  1.369    |
# |  91       | -10.0     |  1.236    |
# |  92       | -9.94     |  1.115    |
# |  93       | -10.0     |  1.221    |
# |  94       | -90.0     |  0.7064   |
# |  95       | -0.46     |  1.068    |
# |  96       | -90.0     |  0.7454   |
# |  97       | -0.62     |  1.069    |
# |  98       | -59.04    |  1.023    |
# |  99       | -7.78     |  1.086    |
# |  100      | -10.0     |  1.44     |
# |  101      | -90.0     |  0.8012   |
# |  102      | -90.0     |  0.6529   |
# |  103      | -10.0     |  1.208    |
# |  104      | -0.5      |  1.067    |
# |  105      | -10.0     |  1.382    |
# |  106      | -90.0     |  0.8375   |
# |  107      | -10.0     |  1.405    |
# |  108      | -0.54     |  1.067    |
# |  109      | -10.0     |  1.196    |
# |  110      | -10.0     |  1.427    |
# |  111      | -10.0     |  1.157    |
# |  112      | -90.0     |  0.9384   |
# |  113      | -0.77     |  1.069    |
# |  114      | -10.0     |  1.291    |
# |  115      | -10.0     |  1.452    |
# |  116      | -8.42     |  1.059    |
# |  117      | -90.0     |  0.9068   |
# |  118      | -10.0     |  1.275    |
# |  119      | -10.0     |  1.321    |
# |  120      | -10.0     |  1.394    |
# |  121      | -10.0     |  1.463    |
# |  122      | -10.0     |  1.347    |
# |  123      | -24.35    |  1.046    |
# |  124      | -10.0     |  1.416    |
# |  125      | -10.0     |  1.311    |
# |  126      | -10.0     |  1.168    |
# |  127      | -90.0     |  0.5851   |
# |  128      | -0.06     |  1.068    |
# |  129      | -0.06     |  1.068    |
# |  130      | -0.03     |  1.068    |
# |  131      | -0.05     |  1.068    |
# |  132      | -0.03     |  1.068    |
# |  133      | -0.06     |  1.068    |
# |  134      | -0.07     |  1.068    |
# |  135      | -0.06     |  1.068    |
# |  136      | -0.06     |  1.068    |
# |  137      | -0.03     |  1.068    |
# |  138      | -0.03     |  1.068    |
# |  139      | -0.04     |  1.068    |
# |  140      | -0.05     |  1.068    |
# |  141      | -0.05     |  1.068    |
# |  142      | -0.04     |  1.068    |
# |  143      | -0.04     |  1.068    |
# |  144      | -0.06     |  1.068    |
# |  145      | -0.04     |  1.068    |
# |  146      | -0.11     |  1.068    |
# |  147      | -0.05     |  1.068    |
# |  148      | -0.05     |  1.068    |
# |  149      | -0.03     |  1.068    |
# |  150      | -0.05     |  1.068    |
# =====================================

# %%
print("Minimum Polyethylene Composition: ", recycle_bo.max, " kg")
# Out:
# Minimum Polyethylene Composition:  {'target': -0.02999999999999936, 'params': {'P': 1.0681245223641245}}  kg

# %%
plastic = 1.0681245223641245

# %%
R = demand*plastic

# %%
plt.figure(figsize=(16, 8), dpi=80)
sns.set(style="darkgrid")

plt.plot(R)
plt.xlabel("Months (t)")
plt.ylabel("Polyethylene Recycled (kg)")
plt.title("Simulation of Total Polyethylene Recycled")
plt.xlim([0, n])
plt.plot(production_cap*plastic, c ='k', linewidth=3.0, linestyle = 'dashed')
#plt.plot(production, c ='k', linewidth=3.0, linestyle = 'dashed')
#plt.axhline(production[60], c='red', linestyle = 'dashed')
plt.axhline(benchmark, c='red', linestyle = 'dashed')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
recycled_df =pd.DataFrame(R.T)

# %%
plt.figure(figsize=(16, 8), dpi=80)
sns.set(style="white")
sns.histplot(recycled_df[5], kde=True)
plt.title("Distribution of Total Polyethylene Recycled in 2028")
plt.xlabel("Polyethylene Recycled (1 million kg)")
plt.axvline(benchmark, c='red', linestyle = 'dashed')
plt.show()

# %%
prob = scs.percentileofscore(recycled_df[5], benchmark)

# %%
print("The probability of recycling above benchmark is:")
print(str(100-prob) + "%")
# Out:
# The probability of recycling above benchmark is:
# 90.0%
